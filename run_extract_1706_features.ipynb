# %%
# !python test_1706_extraction.py
# Out:
# ...
# 🧪 QUICK TEST - Single Patient Extraction (1,706 features)
# ...
#
# ⚙️  Configuration:
#    Data root: ./nsclc/manifest-1603198545583/NSCLC-Radiomics
#    CPU cores: 9
#    Expected features: ~1,706
#
# ...
# 🔍 Scanning for first valid patient...
#    ✅ Found: LUNG1-001
#    CT slices: 134
#    CT dir: nsclc/manifest-1603198545583/NSCLC-Radiomics/LUNG1-001/09-18-2008-StudyID-NA-69331/0.000000-NA-82046
#    SEG file: nsclc/manifest-1603198545583/NSCLC-Radiomics/LUNG1-001/09-18-2008-StudyID-NA-69331/300.000000-Segmentation-9.554/1-1.dcm
#
# ...
# 🚀 EXTRACTING FEATURES
# ...
# Đang load CT DICOM từ: nsclc/manifest-1603198545583/NSCLC-Radiomics/LUNG1-001/09-18-2008-StudyID-NA-69331/0.000000-NA-82046
#   Tìm thấy 134 file DICOM
#   Đã sắp xếp 134 slices
#   CT volume shape: (134, 512, 512), dtype: uint16
#   📍 Extracting: Neoplasm, Primary (segment #1)
#
# ...
# 🚀 FULL FERRETTI FEATURE EXTRACTION (~1,706 features)
# ...
#
# 📊 Image Types Configuration:
#    1. Original:              1 type  → 108 features
# ...

# %%
# !python batch_extract_1706_features.py
# Out:
# ...
# 🚀 BATCH FEATURE EXTRACTION - FERRETTI FULL (1,706 features)
# ...
#
# ⚙️  Configuration:
#    Data root: ./nsclc/manifest-1603198545583/NSCLC-Radiomics
#    Output dir: ./data3d_1706features/outputs
#    CPU cores: 9
#    Expected features: 1706
# [00:51:35] Configuration: 9 CPU cores, 1706 expected features
#
# 📂 Scanning for patients...
#    ✅ Found 421 patients
# [00:51:36] Found 421 patients to process
#
# ...
# 📊 EXTRACTING FEATURES
# ...
#
#
# [1/421] LUNG1-001
# ────────────────────────────────────────────────────────────────────────────────
# Đang load CT DICOM từ: nsclc/manifest-1603198545583/NSCLC-Radiomics/LUNG1-001/09-18-2008-StudyID-NA-69331/0.000000-NA-82046
#   Tìm thấy 134 file DICOM
#   Đã sắp xếp 134 slices
#   CT volume shape: (134, 512, 512), dtype: uint16
#   📍 Extracting: Neoplasm, Primary (segment #1)
#
# ...
# 🚀 FULL FERRETTI FEATURE EXTRACTION (~1,706 features)
# ...
#
# 📊 Image Types Configuration:
#    1. Original:              1 type  → 108 features
# ...

# %%
# !mkdir data3d_1706features/outputs
